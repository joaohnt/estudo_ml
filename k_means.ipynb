# %% [markdown]
# <a href="https://colab.research.google.com/github/joaohnt/estudo_ml/blob/main/k_means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly --upgrade
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Collecting plotly
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from plotly) (1.25.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 12.7 MB/s eta 0:00:00
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed plotly-6.0.0

# %%
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # base salario idade

# %%
from sklearn.cluster import KMeans

# %%
x=[20,  27,  21,  37,  46, 53, 55,  47,  52,  32,  39,  41,  39,  48,  48]
y=[1000,1200,2900,1850,900,950,2000,2100,3000,5900,4100,5100,7000,5000,6500]

# %%
grafico = px.scatter(x = x, y = y)
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="58c905b4-5bcb-4075-9281-c5a178901f11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("58c905b4-5bcb-4075-9281-c5a178901f11")) {                    Plotly.newPlot(                        "58c905b4-5bcb-4075-9281-c5a178901f11",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"FBsVJS41Ny80ICcpJzAw"},"xaxis":"x","y":{"dtype":"i2","bdata":"6AOwBFQLOgeEA7YD0Ac0CLgLDBcEEOwTWBuIE2QZ"},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar" ...

# %%
base_salario = np.array([[20,1000],[27,1200],[21,2900],[37,1850],[46,900],
                        [53,950],[55,2000],[47,2100],[52,3000],[32,5900],
                        [39,4100],[41,5100],[39,7000],[48,5000],[48,6500]])

# %%
base_salario
# Out:
# array([[  20, 1000],
#        [  27, 1200],
#        [  21, 2900],
#        [  37, 1850],
#        [  46,  900],
#        [  53,  950],
#        [  55, 2000],
#        [  47, 2100],
#        [  52, 3000],
#        [  32, 5900],
#        [  39, 4100],
#        [  41, 5100],
#        [  39, 7000],
#        [  48, 5000],
#        [  48, 6500]])

# %%
scaler_salario = StandardScaler()
base_salario = scaler_salario.fit_transform(base_salario)

# %%
base_salario
# Out:
# array([[-1.87963884, -1.11413572],
#        [-1.23255006, -1.01725435],
#        [-1.78719758, -0.19376273],
#        [-0.30813751, -0.70238991],
#        [ 0.52383377, -1.1625764 ],
#        [ 1.17092255, -1.13835606],
#        [ 1.35580506, -0.62972888],
#        [ 0.61627503, -0.5812882 ],
#        [ 1.0784813 , -0.14532205],
#        [-0.77034379,  1.25945777],
#        [-0.12325501,  0.38752547],
#        [ 0.0616275 ,  0.8719323 ],
#        [-0.12325501,  1.79230528],
#        [ 0.70871628,  0.82349162],
#        [ 0.70871628,  1.55010187]])

# %%
kmeans_salario = KMeans(n_clusters=3)
kmeans_salario.fit(base_salario)
# Out:
# KMeans(n_clusters=3)

# %%
centroides = kmeans_salario.cluster_centers_
centroides
# Out:
# array([[ 0.73953003, -0.72661025],
#        [-1.63312883, -0.77505093],
#        [ 0.07703438,  1.11413572]])

# %%
scaler_salario.inverse_transform(kmeans_salario.cluster_centers_)
# Out:
# array([[ 0.73953003, -0.72661025],
#        [-1.63312883, -0.77505093],
#        [ 0.07703438,  1.11413572]])

# %%
grafico1 = px.scatter(x = base_salario[:,0], y = base_salario[:,1], color=kmeans_salario.labels_)
grafico2 = px.scatter(x = centroides[:,0], y = centroides[:,1], size = [12,12,12])
grafico3 = go.Figure(data = grafico1.data + grafico2.data)
grafico3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="dc6e2db0-fe23-4ad0-b597-0852ab1dac27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("dc6e2db0-fe23-4ad0-b597-0852ab1dac27")) {                    Plotly.newPlot(                        "dc6e2db0-fe23-4ad0-b597-0852ab1dac27",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"i4","bdata":"AQAAAAEAAAABAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAIAAAACAAAAAgAAAAIAAAACAAAA"},"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"SmNNLAAT\u002fr+qd5dohrjzv+rTDn5cmPy\u002fqneXaIa407\u002fqWBoMP8PgPxUYw0kZvPI\u002f1TZApmCx9T+qd5dohrjjP7WIhJt1QfE\u002flVW9Aqim6L+p8ovao42\u002fv63yi9qjja8\u002fqfKL2qONv79qlhTFza3mP2qWFMXNreY\u002f"},"xaxis":"x","y":{"dtype":"f8","bdata":"EJZR+X\u002fT8b9zA3d\u002frEbwv9IpqZ03zci\u002f5k3hZvp55r9e3z626Znyv7c6yNe0NvK\u002f+nEZML0m5L9d3z626Zniv1zfPrbpmcK\u002f+3EZML0m9D\u002fVKamdN83YPw9PXpHe5us\u002fXJhLTkit\u002fD9yvIMXC1rqP9QpqZ03zfg\u002f"},"yaxis":"y","type":"scatter"},{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003esize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","size":{"dtype":"i1","bdata":"DAwM"},"sizemode":"area","sizeref":0.03,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"\u002f\u002fXo4zqq5z\u002f15PuwSyH6v6t3l2iGuLM\u002f"},"xaxis":"x","y":{"dtype":"f8","bdata":"NZfOI2RA57\u002fUKamdN83ovxCWUfl\u002f0\u002fE\u002f"},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f ...

# %% [markdown]
# # dados randomicos

# %%
from sklearn.datasets import make_blobs

# %%
X_random, y_random = make_blobs(n_samples = 200, centers = 5)

# %%
X_random[0:10]
# Out:
# array([[ 3.33827185, -6.64293722],
#        [-2.75166956,  3.64805798],
#        [ 4.04237241, -7.19661454],
#        [ 3.36433879, -7.8607811 ],
#        [-2.5275972 ,  4.51681084],
#        [-6.05890918,  0.65336899],
#        [ 3.95476216, -5.19236879],
#        [ 3.40924564, -5.31366633],
#        [ 2.75728267, -5.03015323],
#        [ 2.7393671 , -7.81913627]])

# %%
y_random
# Out:
# array([4, 2, 4, 4, 2, 0, 1, 1, 1, 4, 2, 2, 0, 0, 3, 3, 4, 0, 0, 4, 2, 3,
#        2, 1, 2, 1, 3, 0, 1, 1, 1, 4, 4, 1, 4, 1, 1, 0, 1, 0, 3, 0, 1, 2,
#        3, 1, 0, 0, 2, 2, 3, 4, 1, 1, 0, 3, 2, 4, 2, 2, 4, 0, 4, 3, 0, 0,
#        3, 3, 0, 4, 3, 1, 4, 4, 2, 0, 2, 0, 1, 4, 2, 3, 4, 3, 3, 3, 3, 3,
#        3, 2, 2, 4, 2, 1, 0, 3, 2, 4, 0, 0, 0, 1, 4, 0, 3, 0, 2, 0, 0, 4,
#        3, 3, 2, 0, 0, 4, 4, 2, 4, 4, 0, 1, 1, 1, 1, 2, 3, 0, 2, 3, 4, 2,
#        3, 2, 0, 4, 3, 1, 3, 3, 1, 1, 4, 1, 1, 1, 2, 4, 2, 0, 1, 2, 3, 3,
#        0, 1, 4, 3, 1, 4, 3, 3, 4, 0, 1, 0, 4, 3, 4, 3, 1, 4, 2, 1, 4, 1,
#        2, 2, 3, 0, 2, 1, 2, 3, 2, 4, 4, 2, 3, 1, 0, 0, 2, 3, 1, 2, 0, 0,
#        2, 4])

# %%
grafico = px.scatter(x = X_random[:,0], y = X_random[:,1])
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="52d215d0-0f09-4526-829b-85242404590e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("52d215d0-0f09-4526-829b-85242404590e")) {                    Plotly.newPlot(                        "52d215d0-0f09-4526-829b-85242404590e",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"s1wwGb2XJUDJmqF1v9wlwEIQ1HZCryVAPlLoZ6w4I0DxdqcYOKYhwEoGdTyQLPW\u002f5Qak1tfDHUASwEQIQA8HwKzsvFOvEhJAjPl\u002fPimhAMD7TEMdzAokQPFPJZosmPq\u002fKzQ2yERoIUDAwsf2RfwgQLWel+JS0B5AuNU60eCFCMDu1OGIY08iwNs1V3o0\u002fei\u002frZzv5FjYCkD659neNdwlQPVqASwD3yBA83jc1sLB8r\u002fKUIoo00QhQGOBIDo\u002fniNAaHsi+UnDEECA67hpAC8hQF+M2VeEnyPAcpcd74HBEECb1kfVNFMgQBzJx+fkfRNAMlb0jaju87\u002fYCXxNK8ciQFUNMPNlCiTAGA5fUBWsIUD5g6KX7S0eQEmhEiIHQiLAmysT7SSEHUD1bYEdmXERQABRabws2iNAPjFYWFLGDUAeh1Iw0Nvxv11atDKtwiLAZZH3lH12IkCN3bCEc08jQMsMQJC00yPAd1jWtPuwIkCqHHQEbHkJQGwhUVyoRxBAVfpd\u002ffjDIkC6vY9qSjcUQN5zgTJhDiVAFNuGnhv2GUA8gg0Pa7kjQL9W4s6SYQtAgpbvJleLIUBK0LMgTfUHwJA89ax4RSRAGkn259oyCcCBc\u002f67jHMOQGDc9mKkPCJA0TH23OpO\u002fL8046MBI0MoQMg\u002fU2ZQ7CRA\u002f678CPm1JUC1eWStblIlwKFK24zvmfq\u002fRMjFU5jNIsCdObLz22oiQIC8i0OCugLAbI42c6pqIkA4k0JWCFP7v2SsEhfEUB9AfeStF3pGI0DHxAfi7n4jQOUP9h5OqyRAo9V0oUyVJsAR99AWPucdQNumfd4YpyNAaVWd9PeUHED0Nx5CxAIiQBir+Q0Rnx9AYYM3MicrIcC8PDwNrQ72vzjKuSNEmiNAxRUd1+7rHEBOQruYCP\u002fwv9t2u9Q1QRBAE\u002fEnJTM0BcDNmNr0FvEkwOnezSVtKhJAi+WlbzWbIkCQGZhQoccBwD7EwLmPgQ1AMYbMcxTGJUB+JPDQ0H8kQOeahi4uvSHAvfwfbzk2I8CeA1Om4KAkwAbe98CReyVA\u002fj0SjDZdJcDwAi6FBYQgQLtlrJopJyFAzW388pGNIcDqrQ8jCE4iQN5SAS3FyQ1ATpBvnSOVJEBPRqLnDNgJwIjXxdaQGOO\u002f4BGetH++GkCxt1upFbMjwGL6tW5lTwPAJ1fUqiiPE0A0GrcqHBP9v9Yr4kraGyJAb3aeESFZIUAQne48j1McQAPLwIc4YSTA+qpUBFTOEkAWNjXc7HgjwDIOIbtorSFAImAuq6pOIEAEO9ihyjAjQOYlujiAWAhAVaACe1OCAsAvTeyZ9E8fQD6YDgdLwyNAiPdkYF8hEkDkktNPCzEHwKbfvEkX7B9AMj3XWYajBcCiD5jWszkkwNZ\u002f9D3iyRRA4hsB+CU6IsCegVxhlyEmQBn9YkN7jPK\u002fT8UAgV4yGsAV0pzjLsogwBC5\u002fxsT6SNANqnA1eGmDUBoaVDY9GwdwD6J2DRL6yPALCRpwESbGEDOOAIJ4isjQFtNyjNqzPi\u002fdoMbhqK5AMBRkrMKntkiwL7YCSZddibA8yL59+v7FkAcwxEz3+gjwOqBERRHMx\u002fA2+O1XcDjI8DgC5gaQQ8pQEJpGnLbtvO\u002fQ\u002fn9bZlyI0CISPGLxUggwCf96ApGhgVAk7XUjr5SAsDnjrYt25AgwDiXr7JCitW\u002fK1LL8YioIMCcri6G300hQFLJ2NqbRhRAvnRhKppAEkAcjgKWjIkHwGMohwQKzh9AkI5sLsaNHUCDKQda5CIQQHOhNlo2YvO\u002f+IPufBK1JcDQHEv82TYgQK\u002fygjKbxiHAs6xcdIapGkDT5\u002fdgoUTzv6ytK8zFlBFAhHaTqSR4JMB1qHZCL00KwMtsqXCruyRAUCaoW0Fv9r91\u002fOb7h\u002foeQCvoMVxxPAZAXcHilvCnHEB1hL7d+P0oQHwU8VUHavG\u002f7rlFOonOCUC7yQCu+rcFQKTROts\u002fIgPAuVYCeYx+FEBDaSe984wlQDZTnbv6ZRdAoJZEd0GXIEBqBXUvlaUgQJ\u002fqxNbcdgpA2Lbman0PFUAMnzZY9kYgQIt1PK2MrSTAhkoutyVZDUCC1uGpXhsRQMt\u002fGR94fSPAkkgzGVBpE0Bm0KPR20X5vw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"EFy4UUwrBcBcXj5qsisKQE0reBeDrhDAMtr2YTAeD8A2eqaOppYVQMEM9+kUeAnAx7e5\u002fAdyC8BvK3ixzU4VwI3na9jfaSHAgQv4qd\u002fpCcAFKac+AJ8VwJYCmA8jkBLA3AInUdJnBsD\u002fuW02Du0MwKTAA8hyDBHAst9LwXlrFMBlRlMCwVkUQBgjUq0d6vy\u002fjHEWOcMeHsA+Zi3cLjMMwN31dDpA4ArA8oRWWy5eCcDH0QNFKbcLwHD8L05+YwjAunSbeKwWIsCcn9wO\u002fgwAwPWwI2dwqhNATvmrM8DVGMCMKdpk+wkRwPGEgrJUah\u002fAaMutKPOkDcBcsWjUplQDwGkOkU\u002fxABBAnBFfs3XKDMC4vxmgZRgOwPIWW5LREhFA8cn2OvkODcBJKnVn62MgwATWRftaVhDAHOy1cQbbIMCXKLCm4MIPwLLAVPCkeBZAVZUCeWXSDMCwC49YIDcBwBJkCVh4pRBAFmLG0gdHCMACAIXY2C8dwHGtrqdkYh3AN8czgKY0A8D44WdKbWAhwCT9snfMRfm\u002f5L6990pVIMDVWHcDLC0JwEe5JtP6jSLA\u002f+y7OXERCcAQ\u002fHb9QFEYwMLYF6\u002f3MgvA+nUT0jjyE8DG3NIr6\u002f4fwKQBdfIdJxPAdur1w1uoD8AJzIickhkIwAzAmkS5s\u002fa\u002fcLdTZk9h\u002f799y07LVzgWQOz8w+wS5QLA4Os5P+84EEBm1s\u002fjSQ8OwGWKRui9yBDAnQdkQKo1DMAMwtHVnJIRwPL0E4HOsgbAjBlxvvFZ978CapTEtf0 ...

# %%
kmeans_blobs = KMeans(n_clusters=5)
kmeans_blobs.fit(X_random)
# Out:
# KMeans(n_clusters=5)

# %%
rotulos = kmeans_blobs.predict(X_random)
rotulos
# Out:
# array([4, 1, 4, 4, 1, 2, 0, 2, 3, 2, 4, 2, 0, 0, 0, 2, 1, 2, 3, 4, 0, 2,
#        0, 4, 3, 0, 1, 3, 0, 3, 2, 4, 1, 0, 0, 1, 0, 3, 4, 3, 2, 1, 0, 4,
#        1, 4, 3, 3, 4, 3, 4, 3, 4, 3, 0, 2, 4, 2, 3, 0, 2, 4, 4, 4, 1, 2,
#        1, 0, 2, 0, 2, 0, 4, 4, 4, 1, 0, 4, 0, 0, 0, 1, 2, 4, 0, 2, 3, 2,
#        1, 3, 4, 2, 3, 4, 4, 1, 1, 1, 4, 1, 0, 0, 1, 0, 3, 4, 2, 2, 0, 1,
#        2, 3, 2, 0, 0, 0, 1, 3, 1, 0, 0, 4, 3, 2, 0, 4, 3, 2, 0, 2, 1, 3,
#        1, 4, 2, 1, 1, 4, 3, 1, 1, 3, 4, 2, 2, 1, 1, 3, 1, 1, 1, 4, 2, 4,
#        1, 3, 2, 1, 2, 1, 0, 3, 3, 2, 0, 0, 3, 2, 1, 0, 1, 0, 2, 3, 1, 2,
#        4, 2, 0, 3, 0, 4, 2, 3, 3, 2, 3, 4, 3, 0, 0, 3, 3, 0, 1, 3, 3, 1,
#        3, 2], dtype=int32)

# %%
centroides = kmeans_blobs.cluster_centers_
centroides
# Out:
# array([[ 8.15744455, -3.38516535],
#        [-9.50638591,  4.98703911],
#        [-1.90020656, -3.74923554],
#        [ 4.27597075, -8.17881326],
#        [10.28316843, -3.04824478]])

# %%
grafico1 = px.scatter(x = X_random[:,0], y = X_random[:,1], color = rotulos)
grafico2 = px.scatter(x = centroides[:,0], y = centroides[:,1], size = [5,5,5,5,5])
grafico3 = go.Figure(data = grafico1.data + grafico2.data)
grafico3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="8224cedf-b539-450d-8bbd-68b4c294f9ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8224cedf-b539-450d-8bbd-68b4c294f9ca")) {                    Plotly.newPlot(                        "8224cedf-b539-450d-8bbd-68b4c294f9ca",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"i4","bdata":"..."},"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"s1wwGb2XJUDJmqF1v9wlwEIQ1HZCryVAPlLoZ6w4I0DxdqcYOKYhwEoGdTyQLPW\u002f5Qak1tfDHUASwEQIQA8HwKzsvFOvEhJAjPl\u002fPimhAMD7TEMdzAokQPFPJZosmPq\u002fKzQ2yERoIUDAwsf2RfwgQLWel+JS0B5AuNU60eCFCMDu1OGIY08iwNs1V3o0\u002fei\u002frZzv5FjYCkD659neNdwlQPVqASwD3yBA83jc1sLB8r\u002fKUIoo00QhQGOBIDo\u002fniNAaHsi+UnDEECA67hpAC8hQF+M2VeEnyPAcpcd74HBEECb1kfVNFMgQBzJx+fkfRNAMlb0jaju87\u002fYCXxNK8ciQFUNMPNlCiTAGA5fUBWsIUD5g6KX7S0eQEmhEiIHQiLAmysT7SSEHUD1bYEdmXERQABRabws2iNAPjFYWFLGDUAeh1Iw0Nvxv11atDKtwiLAZZH3lH12IkCN3bCEc08jQMsMQJC00yPAd1jWtPuwIkCqHHQEbHkJQGwhUVyoRxBAVfpd\u002ffjDIkC6vY9qSjcUQN5zgTJhDiVAFNuGnhv2GUA8gg0Pa7kjQL9W4s6SYQtAgpbvJleLIUBK0LMgTfUHwJA89ax4RSRAGkn259oyCcCBc\u002f67jHMOQGDc9mKkPCJA0TH23OpO\u002fL8046MBI0MoQMg\u002fU2ZQ7CRA\u002f678CPm1JUC1eWStblIlwKFK24zvmfq\u002fRMjFU5jNIsCdObLz22oiQIC8i0OCugLAbI42c6pqIkA4k0JWCFP7v2SsEhfEUB9AfeStF3pGI0DHxAfi7n4jQOUP9h5OqyRAo9V0oUyVJsAR99AWPucdQNumfd4YpyNAaVWd9PeUHED0Nx5CxAIiQBir+Q0Rnx9AYYM3MicrIcC8PDwNrQ72vzjKuSNEmiNAxRUd1+7rHEBOQruYCP\u002fwv9t2u9Q1QRBAE\u002fEnJTM0BcDNmNr0FvEkwOnezSVtKhJAi+WlbzWbIkCQGZhQoccBwD7EwLmPgQ1AMYbMcxTGJUB+JPDQ0H8kQOeahi4uvSHAvfwfbzk2I8CeA1Om4KAkwAbe98CReyVA\u002fj0SjDZdJcDwAi6FBYQgQLtlrJopJyFAzW388pGNIcDqrQ8jCE4iQN5SAS3FyQ1ATpBvnSOVJEBPRqLnDNgJwIjXxdaQGOO\u002f4BGetH++GkCxt1upFbMjwGL6tW5lTwPAJ1fUqiiPE0A0GrcqHBP9v9Yr4kraGyJAb3aeESFZIUAQne48j1McQAPLwIc4YSTA+qpUBFTOEkAWNjXc7HgjwDIOIbtorSFAImAuq6pOIEAEO9ihyjAjQOYlujiAWAhAVaACe1OCAsAvTeyZ9E8fQD6YDgdLwyNAiPdkYF8hEkDkktNPCzEHwKbfvEkX7B9AMj3XWYajBcCiD5jWszkkwNZ\u002f9D3iyRRA4hsB+CU6IsCegVxhlyEmQBn9YkN7jPK\u002fT8UAgV4yGsAV0pzjLsogwBC5\u002fxsT6SNANqnA1eGmDUBoaVDY9GwdwD6J2DRL6yPALCRpwESbGEDOOAIJ4isjQFtNyjNqzPi\u002fdoMbhqK5AMBRkrMKntkiwL7YCSZddibA8yL59+v7FkAcwxEz3+gjwOqBERRHMx\u002fA2+O1XcDjI8DgC5gaQQ8pQEJpGnLbtvO\u002fQ\u002fn9bZlyI0CISPGLxUggwCf96ApGhgVAk7XUjr5SAsDnjrYt25AgwDiXr7JCitW\u002fK1LL8YioIMCcri6G300hQFLJ2NqbRhRAvnRhKppAEkAcjgKWjIkHwGMohwQKzh9AkI5sLsaNHUCDKQda5CIQQHOhNlo2YvO\u002f+IPufBK1JcDQHEv82TYgQK\u002fygjKbxiHAs6xcdIapGkDT5\u002fdgoUTzv6ytK8zFlBFAhHaTqSR4JMB1qHZCL00KwMtsqXCruyRAUCaoW0Fv9r91\u002fOb7h\u002foeQCvoMVxxPAZAXcHilvCnHEB1hL7d+P0oQHwU8VUHavG\u002f7rlFOonOCUC7yQCu+rcFQKTROts\u002fIgPAuVYCeYx+FEBDaSe984wlQDZTnbv6ZRdAoJZEd0GXIEBqBXUvlaUgQJ\u002fqxNbcdgpA2Lbman0PFUAMnzZY9kYgQIt1PK2MrSTAhkoutyVZDUCC1uGpXhsRQMt\u002fGR94fSPAkkgzGVBpE0Bm0KPR20X5vw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"EFy4UUwrBcBcXj5qsisKQE0reBeDrhDAMtr2YTAeD8A2eqaOppYVQMEM9+kUeAnAx7e5\u002fAdyC8BvK3ixzU4VwI3na9jfaSHAgQv4qd\u002fpCcAFKac+AJ8VwJYCmA8jkBLA3AInUdJnBsD\u002fuW02Du0MwKTAA8hyDBHAst9LwXlrFMBlRlMCwVkUQBgjUq0d6vy\u002fjHEWOcMeHsA+Zi3cLjMMwN31dDpA4ArA8oRWWy5eCcDH0QNFKbcLwHD8L05+YwjAunSbeKwWIsCcn9wO\u002fgwAwPWwI2dwqhNATvmrM8DVGMCMKdpk+wkRwPGEgrJUah\u002fAaMutKPOkDcBcsWjUplQDwGkOkU\u002fxABBAnBFfs3XKDMC4vxmgZRgOwPIWW5LREhFA8cn2OvkODcBJKnVn62MgwATWRftaVhDAHOy1cQbbIMCXKLCm4MIPwLLAVPCkeBZAVZUCeWXSDMCwC49YIDcBwBJkCVh4pRBAFmLG0gdHCMACAIXY2C8dwHGtrqdkYh3AN8czgKY0A8D44WdKbWAhwCT9snfMRfm\u002f5L6990pVIMDVWHcDLC0JwEe5JtP6jSLA\u002f+y7OXERCcAQ\u002fHb9QFEYwMLYF6\u002f3MgvA+nUT0jjyE8DG3NIr6\u002f4fwKQBdfIdJxPAdur1w1uoD8AJzIickhkIwAzAmkS5s\u002fa\u002fcLdTZk9h\u002f799y07LVzgWQOz8w+wS5QLA4Os5P+84EE ...

# %% [markdown]
# # base cartao de credito

# %%
import pandas as pd
base_cartao = pd.read_csv('/content/credit_card_clients.csv', header = 1)
base_cartao
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         -1  ...          0          0          0         0       689
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0         0         0                           1
# 1          1000      1000         0      2000                           1
# 2          1000      1000      1000      5000                           0
# 3          1200      1100      1069      1000                           0
# 4         10000      9000       689       679                           0
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [30000 rows x 25 columns]

# %%
base_cartao['BILL_TOTAL'] = base_cartao['BILL_AMT1'] + base_cartao['BILL_AMT2'] + base_cartao['BILL_AMT3'] + base_cartao['BILL_AMT4'] + base_cartao['BILL_AMT5'] + base_cartao['BILL_AMT6']

# %%
base_cartao
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0         -1  ...          0          0         0       689         0
# 1          0  ...       3455       3261         0      1000      1000
# 2          0  ...      14948      15549      1518      1500      1000
# 3          0  ...      28959      29547      2000      2019      1200
# 4          0  ...      19146      19131      2000     36681     10000
# ...      ...  ...        ...        ...       ...       ...       ...
# 29995      0  ...      31237      15980      8500     20000      5003
# 29996     -1  ...       5190          0      1837      3526      8998
# 29997     -1  ...      20582      19357         0         0     22000
# 29998      0  ...      11855      48944     85900      3409      1178
# 29999      0  ...      32428      15313      2078      1800      1430
#
#        PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month  BILL_TOTAL
# 0             0         0         0                           1        7704
# 1          1000         0      2000                           1       17077
# 2          1000      1000      5000                           0      101653
# 3          1100      1069      1000                           0      231334
# 4          9000       689       679                           0      109339
# ...         ...       ...       ...                         ...         ...
# 29995      3047      5000      1000                           0      725349
# 29996       129         0         0                           0       21182
# 29997      4200      2000      3100                           1       70496
# 29998      1926     52964      1804                           1      266611
# 29999      1000      1000      1000                           1      230874
#
# [30000 rows x 26 columns]

# %%
X_cartao = base_cartao.iloc[:, [1,25]].values
X_cartao
# Out:
# array([[ 20000,   7704],
#        [120000,  17077],
#        [ 90000, 101653],
#        ...,
#        [ 30000,  70496],
#        [ 80000, 266611],
#        [ 50000, 230874]])

# %%
scaler_cartao = StandardScaler()
X_cartao = scaler_cartao.fit_transform(X_cartao)

# %%
X_cartao
# Out:
# array([[-1.13672015, -0.69069198],
#        [-0.3659805 , -0.66599747],
#        [-0.59720239, -0.44316987],
#        ...,
#        [-1.05964618, -0.52525745],
#        [-0.67427636, -0.00856436],
#        [-0.90549825, -0.10271861]])

# %%
wcss = []
for i in range(1, 11):
  kmeans_cartao = KMeans(n_clusters=i, random_state = 0)
  kmeans_cartao.fit(X_cartao)
  wcss.append(kmeans_cartao.inertia_)

# %%
wcss
# Out:
# [59999.99999999962,
#  35197.83439125732,
#  20128.20263562325,
#  15892.249716910846,
#  10708.603774943429,
#  8604.404544864514,
#  7684.904846136829,
#  6593.001391781384,
#  5669.721586002757,
#  5055.083531903275]

# %%
grafico = px.line(x = range(1,11), y = wcss)
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="a20141ec-e181-482f-8165-39a81c985c36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a20141ec-e181-482f-8165-39a81c985c36")) {                    Plotly.newPlot(                        "a20141ec-e181-482f-8165-39a81c985c36",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AQIDBAUGBwgJCg=="},"xaxis":"x","y":{"dtype":"f8","bdata":"zP\u002f\u002f\u002f\u002f9L7UBIS1Wzui\u002fhQLdn+\u002fcMqNNArEa59h8Kz0AWUn9ITerEQG1JIMgzzsBAmBX\u002fo+cEvkCHNzZbAMG5QBg73Lm4JbZAvchYYhW\u002fs0A="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinew ...

# %%
kmeans_cartao = KMeans(n_clusters = 4, random_state = 0)
rotulos = kmeans_cartao.fit_predict(X_cartao)

# %%
grafico = px.scatter(x = X_cartao[:,0], y = X_cartao[:,1], color = rotulos)
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="32685bf0-7ec7-4fd8-9171-4e0f36b68b03" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("32685bf0-7ec7-4fd8-9171-4e0f36b68b03")) {                    Plotly.newPlot(                        "32685bf0-7ec7-4fd8-9171-4e0f36b68b03",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"i4","bdata":"..."},"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":{"dtype":"f8","bdata":"PZG8dgEw8r+5DO55OWzXv5nb6jFIHOO\u002fPk2FeNf57L8+TYV41\u002fnsvz5NhXjX+ey\u002fUQxxGK2ABEAvP0Rg5KTgvyg2p2ZUHcu\u002fPZG8dgEw8r\u002fcuXugAwrQP2aHJbpY0eY\u002fp4jOgbGEDEBrFDjVDwvov\u002f3qfuj0WeQ\u002fPk2FeNf57L89kbx2ATDyv++YBtLXzvI\u002fwtFTdZ+99z\u002fbIIVn0bG4P+fToNZxfdK\u002fuQzueTls179rFDjVDwvov83IYFJwawFAmdvqMUgc478+TYV41\u002fnsv9Ww3qZzguq\u002fPk2FeNf57L8+TYV41\u002fnsvz5NhXjX+ey\u002fVGRjilrW3j8+TYV41\u002fnsvy8\u002fRGDkpOC\u002fUQxxGK2ABEBRDHEYrYAEQHRLyWXXiK2\u002fOcByXSDA6z\u002fVsN6mc4Lqvz5NhXjX+ey\u002fOcByXSDA6z\u002fC0VN1n733P2sUONUPC+i\u002fct+PX7Nr878oNqdmVB3Lv6fpK0o7ce+\u002fr\u002fLIQ8v41D89kbx2ATDyv4PEDCDFP8G\u002fK276RgM1+j89kbx2ATDyv2sUONUPC+i\u002fLz9EYOSk4L+6SjPpJZPxP9sghWfRsbg\u002fg8QMIMU\u002fwb9RDHEYrYAEQNsghWfRsbg\u002f2yCFZ9GxuD\u002fcuXugAwrQP5UKoRhnrPw\u002fUQxxGK2ABEBrFDjVDwvovz5NhXjX+ey\u002fPk2FeNf57L\u002fn06DWcX3Sv9y5e6ADCtA\u002fct+PX7Nr87+v8shDy\u002fjUP+fToNZxfdK\u002fPZG8dgEw8r8CeJEDrJPlv++YBtLXzvI\u002f3Ll7oAMK0D+iXBkvhDfuP1g1raM7RvU\u002fPZG8dgEw8r8+TYV41\u002fnsv4b8XwB0V\u002fA\u002fCEPpjU\u002f08L+TTtgWkeLhPwIXNDsipwJAwtFTdZ+99z\u002fVsN6mc4Lqv5UKoRhnrPw\u002fPk2FeNf57L90S8ll14itv8LRU3Wfvfc\u002fdEvJZdeIrb\u002fn06DWcX3Svz2RvHYBMPK\u002f3Ll7oAMK0D85wHJdIMDrPy8\u002fRGDkpOC\u002fdEvJZdeIrb\u002fVsN6mc4Lqv5nb6jFIHOO\u002fwtFTdZ+99z+DxAwgxT\u002fBvz5NhXjX+ey\u002fPZG8dgEw8r8oNqdmVB3Lvytu+kYDNfo\u002fHL6dL\u002ftEA0A+TYV41\u002fnsv9Ww3qZzguq\u002faxQ41Q8L6L8CeJEDrJPlv42DgIztgfY\u002f59Og1nF90r\u002fC0VN1n733PyTn2bqJCvQ\u002fPk2FeNf57L85wHJdIMDrPy8\u002fRGDkpOC\u002fPk2FeNf57L8IQ+mNT\u002fTwv5NO2BaR4uE\u002fAniRA6yT5b+VCqEYZ6z8P5NO2BaR4uE\u002fPk2FeNf57L\u002fNyGBScGsBQIxFOx0BW9y\u002fukoz6SWT8T89kbx2ATDyvz2RvHYBMPK\u002f3Ll7oAMK0D\u002fbIIVn0bG4Pz5NhXjX+ey\u002f1bDepnOC6r8IQ+mNT\u002fTwv5NO2BaR4uE\u002f\u002fqZH6soj\u002fz8k59m6iQr0PwhD6Y1P9PC\u002fk07YFpHi4T+DxAwgxT\u002fBv6\u002fyyEPL+NQ\u002fPk2FeNf57L8+TYV41\u002fnsv5NO2BaR4uE\u002f2yCFZ9GxuD8+TYV41\u002fnsv0L2QGnL2pM\u002fPZG8dgEw8r8+TYV41\u002fnsv0L2QGnL2pM\u002f3Ll7oAMK0D8CeJEDrJPlv2aHJbpY0eY\u002fKDanZlQdy78CeJEDrJPlv42DgIztgfY\u002fOcByXSDA6z8IQ+mNT\u002fTwvyg2p2ZUHcu\u002f3Ll7oAMK0D\u002fcuXugAwrQP6\u002fyyEPL+NQ\u002fPk2FeNf57L8IQ+mNT\u002fTwvz5NhXjX+ey\u002folwZL4Q37j\u002f96n7o9FnkP9Ww3qZzguq\u002fjEU7HQFb3L\u002f2HydeUfn4Py8\u002fRGDkpOC\u002fmdvqMUgc478+TYV41\u002fnsv9AjzIu8SOk\u002fhvxfAHRX8D8+TYV41\u002fnsvz5NhXjX+ey\u002fwtFTdZ+99z\u002fn06DWcX3SvwJ4kQOsk+W\u002fPk2FeNf57L89kbx2ATDyvwJ4kQOsk+W\u002fk07YFpHi4T8CeJEDrJPlv1EMcRitgARA1bDepnOC6r89kbx2ATDyvy8\u002fRGDkpOC\u002fwtFTdZ+99z\u002fcuXugAwrQP+fToNZxfdK\u002fPZG8dgEw8r+6SjPpJZPxP9Ww3qZzguq\u002f2yCFZ9GxuD\u002fbIIVn0bG4Pz5NhXjX+ey\u002fPk2FeNf57L+DxAwgxT\u002fBvz2RvHYBMPK\u002fUQxxGK2ABEAIQ+mNT\u002fTwv9sghWfRsbg\u002fKDanZlQdy78oNqdmVB3Lv7kM7nk5bNe\u002fwtFTdZ+99z89kbx2ATDyvy8\u002fRGDkpOC\u002fr\u002fLIQ8v41D8CeJEDrJPlvyTn2bqJCvQ\u002fgisW55Ln2T+v8shDy\u002fjUP6fpK0o7ce+\u002fCEPpjU\u002f08L8CFzQ7IqcCQAhD6Y1P9PC\u002fk07YFpHi4T8CeJEDrJPlv4xFOx0BW9y\u002fukoz6SWT8T\u002fC0VN1n733PyTn2bqJCvQ\u002fhvxfAHRX8D\u002fvmAbS187yPz5NhXjX+ey\u002fQvZAacvakz+Ng4CM7YH2Pz2RvHYBMPK\u002fPk2FeNf57L89kbx2ATDyvz5NhXjX+ey\u002fPZG8dgEw8r8+TYV41\u002fnsvxMCXf ...

# %%
lista_clientes = np.column_stack((base_cartao, rotulos))
lista_clientes
# Out:
# array([[     1,  20000,      2, ...,      1,   7704,      0],
#        [     2, 120000,      2, ...,      1,  17077,      0],
#        [     3,  90000,      2, ...,      0, 101653,      0],
#        ...,
#        [ 29998,  30000,      1, ...,      1,  70496,      0],
#        [ 29999,  80000,      1, ...,      1, 266611,      0],
#        [ 30000,  50000,      1, ...,      1, 230874,      0]])

# %%
lista_clientes = lista_clientes[lista_clientes[:,26].argsort()]
lista_clientes
# Out:
# array([[     1,  20000,      2, ...,      1,   7704,      0],
#        [ 22742,  80000,      2, ...,      0, 330716,      0],
#        [ 22736,  60000,      2, ...,      0,  76973,      0],
#        ...,
#        [ 27952, 280000,      2, ...,      0,      0,      3],
#        [   931, 260000,      2, ...,      0, 339021,      3],
#        [ 19905, 210000,      2, ...,      0,   4580,      3]])

# %% [markdown]
# usando + atributos

# %%
base_cartao.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'BILL_TOTAL'],
#       dtype='object')

# %%
X_cartao_mais = base_cartao.iloc[:,[1,2,3,4,5,25]].values
X_cartao_mais
# Out:
# array([[ 20000,      2,      2,      1,     24,   7704],
#        [120000,      2,      2,      2,     26,  17077],
#        [ 90000,      2,      2,      2,     34, 101653],
#        ...,
#        [ 30000,      1,      2,      2,     37,  70496],
#        [ 80000,      1,      3,      1,     41, 266611],
#        [ 50000,      1,      2,      1,     46, 230874]])

# %%
scaler_cartao_mais = StandardScaler()
X_cartao_mais = scaler_cartao_mais.fit_transform(X_cartao_mais)

# %%
X_cartao_mais
# Out:
# array([[-1.13672015,  0.81016074,  0.18582826, -1.05729503, -1.24601985,
#         -0.69069198],
#        [-0.3659805 ,  0.81016074,  0.18582826,  0.85855728, -1.02904717,
#         -0.66599747],
#        [-0.59720239,  0.81016074,  0.18582826,  0.85855728, -0.16115646,
#         -0.44316987],
#        ...,
#        [-1.05964618, -1.23432296,  0.18582826,  0.85855728,  0.16430256,
#         -0.52525745],
#        [-0.67427636, -1.23432296,  1.45111372, -1.05729503,  0.59824792,
#         -0.00856436],
#        [-0.90549825, -1.23432296,  0.18582826, -1.05729503,  1.14067961,
#         -0.10271861]])

# %%
wcss = []
for i in range(1, 11):
  kmeans_cartao_mais = KMeans(n_clusters=i, random_state = 0)
  kmeans_cartao_mais.fit(X_cartao_mais)
  wcss.append(kmeans_cartao_mais.inertia_)

# %%
grafico = px.line(x = range(1,11), y = wcss)
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="3274204f-082a-4fd8-bb2f-57b7f651bebb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3274204f-082a-4fd8-bb2f-57b7f651bebb")) {                    Plotly.newPlot(                        "3274204f-082a-4fd8-bb2f-57b7f651bebb",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AQIDBAUGBwgJCg=="},"xaxis":"x","y":{"dtype":"f8","bdata":"5P\u002f\u002f\u002f\u002f\u002f4BUFBSnE3DIkBQWbN52KcNv5AHknnKNKF+kDXUa6YWWf3QCwpaOYQavVA00+G1Smb80B9HCkVyYjyQNxvxql20vFASau8hnQM8UA="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks" ...

# %%
kemans_cartao_mais = KMeans(n_clusters=2, random_state=0)
rotulos = kmeans_cartao_mais.fit_predict(X_cartao_mais)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_cartao_mais_pca = pca.fit_transform(X_cartao_mais)

# %%
X_cartao_mais_pca.shape
# Out:
# (30000, 2)

# %%
grafico = px.scatter(x = X_cartao_mais_pca[:,0], y = X_cartao_mais_pca[:,1], color = rotulos)
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="c38e9bf4-3b18-4f27-ae6c-270ecfbea409" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c38e9bf4-3b18-4f27-ae6c-270ecfbea409")) {                    Plotly.newPlot(                        "c38e9bf4-3b18-4f27-ae6c-270ecfbea409",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"i4","bdata":"..."},"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":{"dtype":"f8","bdata":"78lxSc205792ox7eMK\u002f3v4Y2nPriUO6\u002fNftkDDAj2T+U4PyuTNv8Px0i2RLeyuy\u002fInWqGcNz+D+DEhGeTdv7v4ZOPUYfYsU\u002f2YBA03e\u002f5r8z7S\u002f1qZPbv\u002fBzBQJX+Nc\u002fsN0tMOem7D+osaVuikDvv1zJnkA3keq\u002fVdSpO+XTBMBRQ2CO43f\u002fv6xqJdztZgJAxDTWvbA8+T\u002fbzxvtWYz2v7d5V77ZM8q\u002f9J7+7O124T8fEVOnZ+H2vxX0R9Q\u002faPM\u002fmrfM9NCD\u002fr9M3I\u002f38CL1vyaB7qAuvvu\u002fSOBBPJui8L+CnZkOXITzP8mU1e41IPy\u002fri+6IIJX9b8BpEO4Yqruv\u002fgCx1depO2\u002fsk4sZYM+BUBf6unKtNIFQIWIjuYk+\u002fO\u002fNxbh5n\u002fq\u002fj8syApvV2f+v2DaukkYWP6\u002fM5Jcb3Qn678iE9VxKBPlP53M3Jcs9vq\u002fr+0EzQ+X\u002fr+ey8y+Q6TnP\u002fH2rAESkvm\u002fkk+HUZ9K878twaCgJP4BwLc8FYDFs+k\u002f6fTrsh3tyL+YE5HHLlv\u002fvwIi8ss5DKg\u002fJKkhoVrK8L\u002fArsdkGyH8P+86bvnk7ve\u002fFvnhTW++9b\u002fs+JJ8GcX6PzF6z03jo+U\u002ftRXQKBTI8D+sRbr9FSTwv33DczKw9gFArmvChbYv8j+qdheQGfLmPzjIPCLNH\u002fi\u002f8e6MWG1S7D\u002f4BfvsV1j2P\u002f\u002fzszM8agFAz\u002fU7jAwW+T\u002fOTjjyfRn0v32uwwO0Ou+\u002ftbwDFU8G8L8scJbOPHv2v5rwS4MwJ9i\u002f8v0oQ5if0j9pIjYNqzfivyJ2\u002fjEt2uG\u002f11OYleoP+786Yan8H73zv3dU6\u002fKBXPI\u002fivd4nHZL\u002fr+3u2rCftKsP08g9MJ+nOC\u002fB\u002fKnXjPX7b9KET59GLLrv8OtXXAHAgFAKeyGFtwG1D+mgfP0Pg7Tv+41+Oea4fQ\u002f0KPPvR2C7r90oCEARzTHP+UyqhTDT7G\u002fY4PqdV5\u002fAUDfgIaordncv77tLeqrCfy\u002fDv7TbAR04D9FLCZ7aWH7v7j5+fvEOOK\u002fCQAKth9U9T9UG9QK+Gryvz08IckS0t2\u002fQt1caJ4k2j9nHxipRcDyv6PSyGVIJ+e\u002fZfyI3+rtE0AoHYAGsVj4v7xiYb1EaPa\u002fAlQmHnHK+790XuGGFqLPP18IGWGp5ec\u002fmSnAm4zJlr998+z2qE\u002fwP1MgAX9VRec\u002fduDwtqIj9j+SUnIYV4T9P5A6e68ze\u002fu\u002fq8r2F2Ou27\u002fUNfmNCev+vwpvTcnlDfO\u002ftzhE1ilk9r9GQMrJX7jxPzB+FNi1Dsq\u002fOnP0eY9207\u002fN2k3h1Bn1P6cg2qGJcus\u002f9QQSb4Ah\u002fz9qs7cJExr8v8puy8rAVv2\u002f31dICdys9T8\u002fU5P43HXqP7G5fgaaWPU\u002fAkEJ6AKrAEBwX2LbYIEBwAY1Png84tK\u002f\u002f4Z3pgC0AEAc3Wb+csQHQCfgCQrvl\u002f6\u002fvaZJPDQ\u002f5j\u002fvjA6KQ1r2v2QSRvr6d9k\u002fV5fNzeOG9z\u002fhsBbeAQj9vyR+Wv7U4rs\u002fihkYjTAi8b\u002fwRPa92e76v\u002fD9qzskae+\u002fYV+etfHl+r8FuZOa6376v3pzmaz9evO\u002flDzSOHHt0794we9DGaXjvxIpJ0MItABAoRNIYuFF4T\u002f4Xx5FTx\u002f6v4dtTSPEeIu\u002fONaruRitBkAWucS381r2vzumGdMZvNA\u002feUTVup3w2L9dBMD9ggqCPw3lw5YlcQFAtIAQpQJ9AEDHmkpwt2vnv6Fd1okyp\u002fe\u002fkmLw\u002fMIY\u002fz\u002fpdrUSlrHtPxkfA92dTe8\u002fnrIZHw1l9b9NrZUpmWDmP7WU5T2AEpM\u002fWNOr1tYe4T8aobzvNjT9v17ysjPNE7e\u002f1OXKbjlQ8L8B79z3\u002fpH+v6UpzoYCzADAC+Dv9okV6r97exuPy4YDQKuOY1kZbfe\u002fakP3jTXV8b911kWtSnj\u002fv7zJe2v2+oe\u002fEIyWfz5\u002f37\u002fAd9vxFmHjv0HsAAEXzQFAXdEQAenD3r9JBoA+jIz6v1UW6ZagZ98\u002fnpavwzO0478HxrycvLz0P87inu1cNdE\u002fFJYQBUQX9b9SO\u002f06rt7evwacOmQBPPy\u002fJOGaDe8D9r9YYaxEP0D7vz9N6ovu9dU\u002fKB9yzQjN\u002fr+7aL1dlu7RP3EDNZ4r2gHAGzXMp05Q7T+9KymMUzL6v+VjnR2woNY\u002fjcYCDQB98r8Mj09v9cP6vy+QAqtoveu\u002fJQvww\u002fxJBUB1DlTAcY\u002fwPx8pJkMlgOw\u002fUTUdKC+K7T85x7Pb3zL3vxgabzsMUPk\u002f2eKSpm9987\u002fR7Rv01LPbP0eDus8Dv\u002fA\u002fn9lRMo5D5L9+xHfxGxTxP9tReQKWie0\u002fBIXGYPuw5D8VrcJsDVHcv3+UqKiLivs\u002fMvxENMyt3L+9+5gT1k\u002f3P7unJ0UkwgBAdtMYIGtI5D+FOQpnzjTGv83cGRd7pN2\u002fZhAGaK4u7r9Vz1iDllr+P4RkP0N\u002fdNY\u002fkX0zO2G8+b9IfLgGrwr5v3pJ6SQh6v+\u002fTt250SU9\u002fL95BI16dcTQv7+4+vl2ZKG\u002f+9RPeNWKuj+VmoD6KKD ...
